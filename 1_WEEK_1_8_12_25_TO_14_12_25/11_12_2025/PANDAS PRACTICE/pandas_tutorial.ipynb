# %% [markdown]
# ### Pandas Dataframe

# %%
import pandas as pd

# %%
df  = pd.DataFrame({
    'Name' : ['Tofik','Abrar','Musab'],
    'Age' : [21,22,23]
})

# %% [markdown]
# ### Attributes in Data Frame

# %%
df

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %% [markdown]
# ### Accessing Data
# ######    **loc means using lables**
# ######    **iloc means using indexes**

# %%
print(df.loc[0])
print(df.iloc[1:3])

# %% [markdown]
# #### Methods in Data Frame

# %%
# head() is used to retrieve initial rows
df.head()

# %%
# tail() is used to retrieve last rows
df.tail()
# Out:
#     Name  Age
# 0  Tofik   21
# 1  Abrar   22
# 2  Musab   23

# %%
# info() is used to get information about your data frame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
# describe() is used to get statistical information about your data frame 
df.describe()
# Out:
#         Age
# count   3.0
# mean   22.0
# std     1.0
# min    21.0
# 25%    21.5
# 50%    22.0
# 75%    22.5
# max    23.0
