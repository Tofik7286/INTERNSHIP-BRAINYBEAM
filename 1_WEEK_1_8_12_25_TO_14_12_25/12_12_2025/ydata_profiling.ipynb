# %% [markdown]
# #### importing all libraries

# %%
import numpy as np
import pandas as pd
import ydata_profiling as yp

# %% [markdown]
# #### Load data set

# %%
df = pd.read_csv('flight.csv')
df.head()

# %% [markdown]
# ### Using ydata profiling (1st method)

# %%
yp.ProfileReport(df)

# %% [markdown]
# #### 2nd method of ydata profiling

# %%
from ydata_profiling import ProfileReport

# %%
pro = ProfileReport(df)
pro

# %% [markdown]
# #### 3rd method (in this method we can export our report to any file such as html,json etc)

# %%
pro = ProfileReport(df, title="Flight Report")
pro.to_file(output_file="Flight_dataset.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
